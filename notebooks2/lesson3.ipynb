# %% [markdown]
# Benefits of Understanding ML Groupings
# - The state of the machine learning nation:
# * Total ML algorithms:>100
# * Total ML use cases:>100
# - It's important to understand ways to group them in order to decrease time-to-value by hastening the model selection process.

# %% [markdown]
# Popular Ways to Group ML Algorithms
# * By Learning Style:
# - Supervised
# - Unsupervised
# - Semi-supervised
#
# * By Function:
# - Regression
# - Clustering
# - Dimension reduction
# - Association rules
# - Deep learning
# - Instance-based
# - Decision trees
# - Bayesian
# - Ensemble
# - Regularization

# %% [markdown]
# Based on Learning Style: Supervised
# - Instance-based classification: classification learns from labeled data to predict categories for new data points; the class labels are discrete, unordered values

# %% [markdown]
# Unsupervised
# - Dimensionality reduction: takes unlabeled, continuous high-dimensional data and compresses it into a smaller synthetic representation

# %% [markdown]
# Machine Learning Road Map
# 1. Data ingestion
# 2. Model training
# 3. Initial predictions
# 4. Optimization
# 5. Final predictions

# %% [markdown]
# Machine Learning Models Roads Map
# 1. Clustering models
# 2. Dimension reduction methods
# 3. Regression models
# 4. Other popular ML methods
# 5. Natural language processing
# 6. Generative AI models
