# %% [markdown]
# Visualizing time series

# %% [markdown]
# TIME SERIES
# A time series is a measure of unit change over time for any variable under observation. The built-in Python module datetime supplies classes for manipulating dates and times in both simple and complex ways.

# %% [markdown]
# Spotting Trend and Seasonality
# - Constant Time Series
# - Trended Time Series
# - Untrended Seasonal Time Series
# - Trended Seasonal Time Series

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sns.set_style('whitegrid')

# %% [markdown]
# The simples time series plot

# %%
address = '../data/Superstore-Sales.csv'

df = pd.read_csv(address, encoding='cp1252', parse_dates=True)

df.head()
# Out:
#    Row ID  Order ID  ... Product Base Margin   Ship Date
# 0       1         3  ...                0.80  10/20/2010
# 1      49       293  ...                0.58   10/2/2012
# 2      50       293  ...                0.39   10/3/2012
# 3      80       483  ...                0.58   7/12/2011
# 4      85       515  ...                0.50   8/30/2010
#
# [5 rows x 21 columns]

# %%
df['Order Quantity'].plot()
# Out:
# <Axes: >

# %%
df2 = df.sample(n=100, random_state=25, axis=0)

plt.xlabel('Order Date')
plt.ylabel('Order Quantity')

plt.title('Superstore Sales')

df2['Order Quantity'].plot()
# Out:
# <Axes: title={'center': 'Superstore Sales'}, xlabel='Order Date', ylabel='Order Quantity'>
