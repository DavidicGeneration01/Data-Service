# %% [markdown]
# Asynchronous Scraping Libraries
# - aiohttp - allows for asynchronous requests
# - asyncio - allows for concurrent coding

# %%
pip install aiohttp
# Out:
# Requirement already satisfied: aiohttp in c:\Users\David-Alade\Documents\Data Service\.venv\Lib\site-packages (3.13.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\David-Alade\Documents\Data Service\.venv\Lib\site-packages (from aiohttp) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\David-Alade\Documents\Data Service\.venv\Lib\site-packages (from aiohttp) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\Users\David-Alade\Documents\Data Service\.venv\Lib\site-packages (from aiohttp) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\David-Alade\Documents\Data Service\.venv\Lib\site-packages (from aiohttp) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\David-Alade\Documents\Data Service\.venv\Lib\site-packages (from aiohttp) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\David-Alade\Documents\Data Service\.venv\Lib\site-packages (from aiohttp) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\David-Alade\Documents\Data Service\.venv\Lib\site-packages (from aiohttp) (1.23.0)
# Requirement already satisfied: idna>=2.0 in c:\Users\David-Alade\Documents\Data Service\.venv\Lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp) (3.13)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install asyncio
# Out:
# Requirement already satisfied: asyncio in c:\Users\David-Alade\Documents\Data Service\.venv\Lib\site-packages (4.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import csv
import re

# %%
# !pip install nest-asycio
import nest_asyncio
nest_asyncio.apply()

# %%
async def scrap_and_save_links(text):
    soup = BeautifulSoup(text, 'html.parser')
    with open('csv_file.csv', 'a', newline='') as file:
        writer = csv.writer(file, delimiter=',')
        for link in soup.findAll('a', attrs={'href': re.compile('^https')}):
            link = link.get('href')
            writer.writerow([link])
        file.close()

# %%
async def fetch(session, url):
    try:
        async with session.get(url) as response:
            text = await response.text()
            task = asyncio.create_task(scrap_and_save_links(text))
            await task
    except Exception as e:
        print(str(e))

# %%
async def scrap(urls):
    tasks = []
    async with aiohttp.ClientSession() as session:
        for url in urls:
            tasks.append(fetch(session,url))
        await asyncio.gather(*tasks)

# %%
urls = ['https://analytics.usa.gov/', 'https://www.python.org/', 'https://www.linkedin.com/']
asyncio.run(scrap(urls=urls))
# Out:
# Timeout context manager should be used inside a task
# Timeout context manager should be used inside a task
# Timeout context manager should be used inside a task
