# %% [markdown]
# Web Scraping: It involves scrapping website for informations, relative data for analysis, prediction and forcast.
#
# Why Web Scraping?
# - Company information
# - Schemas, Charts, Tables, Graphs
# - Search Engines
# - HTML Website
# - News Sources
# - Social Media
# - Pricing Website
# - RSS Feeds

# %% [markdown]
# Why Wev Scraping?
# - Website
# - Scrapper Bot
# - Unstructured Data
# - Structured Data

# %% [markdown]
# Applications of Web Scraping
# * The usefulness of web scraping as a whole:
# - Critical to generative AI, machine learning, and data analytics
# - Supports comprehensive market research and competitive analysis
# - Facilitates website migration by transferring data from one site to another

# %% [markdown]
# Python requests for automating data collection
# => Features of Requests Library
# - HTTP requests
# - Connections
# - Response headers
# - Content types
# - Response content

# %% [markdown]
# Python requests for automating data collection

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# %%
response = requests.get('https://www.python.org')
response
# Out:
# <Response [200]>

# %% [markdown]
# Headers

# %%
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '11942', 'x-frame-options': 'SAMEORIGIN', 'content-encoding': 'gzip', 'server': 'nginx', 'via': '1.1 varnish, 1.1 varnish, 1.1 varnish', 'content-type': 'text/html; charset=utf-8', 'Accept-Ranges': 'bytes', 'Date': 'Wed, 29 Apr 2026 09:57:21 GMT', 'Age': '2871', 'X-Served-By': 'cache-iad-kiad7000081-IAD, cache-iad-kiad7000081-IAD, cache-par-lfpg1960043-PAR', 'X-Cache': 'MISS, HIT, HIT', 'X-Cache-Hits': '0, 176, 8', 'X-Timer': 'S1777456642.607643,VS0,VE0', 'Vary': 'Cookie', 'Strict-Transport-Security': 'max-age=63072000; includeSubDomains; preload'}

# %% [markdown]
# Content Types

# %%
response.headers['Content-Type']
# Out:
# 'text/html; charset=utf-8'

# %% [markdown]
# Body/Content

# %%
response.content
# Out:
# b'<!doctype html>\n<html class="no-js" lang="en" dir="ltr">\n\n<head>\n    <script defer\n            file-types="bz2,chm,dmg,exe,gz,json,msi,msix,pdf,pkg,tgz,xz,zip"\n            data-domain="python.org"\n            src="https://analytics.python.org/js/script.file-downloads.outbound-links.js"></script>\n\n    <meta charset="utf-8">\n\n    <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js">\n    <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js">\n\n    <meta name="application-name" content="Python.org">\n    <meta name="apple-mobile-web-app-title" content="Python.org">\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="apple-mobile-web-app-status-bar-style" content="black">\n\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="HandheldFriendly" content="True">\n    <meta name="format-detection" content="telephone=no">\n\n    <script asyn
# ...

# %%
import difflib

# %%
flines = 'Hello. How are you? I am fine.'
glines = 'How are you, Lillian? I am doing well.'

# %%
d = difflib.Differ()
diff = d.compare(flines, glines)

for line in diff:
    print(line)
# Out:
# - H
# - e
# - l
# - l
# - o
# - .
# -
#   H
#   o
#   w
#
#   a
#   r
#   e
#
#   y
#   o
#   u
# + ,
# +
# + L
# + i
# + l
# + l
# + i
# + a
# + n
#   ?
#
#   I
#
#   a
#   m
#
# - f
# + d
# + o
#   i
#   n
# + g
# +
# + w
#   e
# + l
# + l
#   .
